# %% [markdown]
# # dataset load using imageio and pandas

# %%
#import the pandas library
import pandas as pd
#Read the Iris dataset
df = pd.read_csv ("C:/Users/이태호/Desktop/대학교/3학년/2학기/인공지능/개발자를 위한 머신 러닝/Machine-Learning-for-Developers-code-updates/Chapter02/Code/data/iris.csv",
                  engine='python')
#Get the columns name
print(df.columns)
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
print(df["Sepal.Length"].mean())
print(df["Sepal.Length"].var())
print(df["Sepal.Length"].skew())
print(df["Sepal.Length"].kurtosis())
# Out:
# 5.843333333333335
# 0.6856935123042505
# 0.3149109566369728
# -0.5520640413156395

# %%
#Get the 3 first elements ()
df.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
#Get the first 3 elements of a determined column
df[u'Sepal.Length'].head(3)
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# Name: Sepal.Length, dtype: float64

# %%
#Describe the sepal lenght column
print("Mean: " + str (df[u'Sepal.Length'].mean()))
print("Standard deviation: " + str(df[u'Sepal.Length'].std()))
print("Kurtosis: " + str(df[u'Sepal.Length'].kurtosis()))
print("Skewness: " + str(df[u'Sepal.Length'].skew()))
# Out:
# Mean: 5.843333333333335
# Standard deviation: 0.8280661279778629
# Kurtosis: -0.5520640413156395
# Skewness: 0.3149109566369728

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df[u'Sepal.Length'].plot.hist()

# %%
import imageio
from matplotlib import pyplot as plt
# %matplotlib inline
testimg = imageio.imread("C:/Users/이태호/Desktop/대학교/3학년/2학기/인공지능/개발자를 위한 머신 러닝/Machine-Learning-for-Developers-code-updates/Chapter02/Code/data/blue_jay.jpg")
plt.imshow(testimg)

# %%
testimg.shape
# Out:
# (1416, 1920, 3)

# %%
plt.subplot(131)
plt.imshow( testimg[:,:,0], cmap="Reds")
plt.title("Red channel")

plt.subplot(132)
plt.imshow( testimg[:,:,1], cmap="Greens")
plt.title("Green channel")

plt.subplot(133)
plt.imshow( testimg[:,:,2], cmap="Blues")
plt.title("Blue channel")
# Out:
# Text(0.5,1,'Blue channel')
